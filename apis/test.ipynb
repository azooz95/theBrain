# %%
from fastapi import APIRouter, FastAPI

app = FastAPI()
internal_router = APIRouter()

@internal_router.get("/users/")
def read_users():
    return [{"name": "Rick"}, {"name": "Morty"}]

app.include_router(internal_router)

# For running inside Jupyter Notebook
import nest_asyncio
import uvicorn

nest_asyncio.apply()

config = uvicorn.Config(app, host="localhost", port=8000, log_level="info")
server = uvicorn.Server(config)
await server.serve()
# Out:
# INFO:     Started server process [39106]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://localhost:8000 (Press CTRL+C to quit)
# INFO:     127.0.0.1:47458 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:47466 - "GET /favicon.ico HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:35488 - "GET /users/ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35500 - "GET /favicon.ico HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:35488 - "GET /users/ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35500 - "GET /favicon.ico HTTP/1.1" 404 Not Found
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [39106]
